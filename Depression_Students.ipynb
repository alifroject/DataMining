# %% [markdown]
# <a href="https://colab.research.google.com/github/alifroject/DataMining/blob/main/Depression_Students.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ikynahidwin/depression-student-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /root/.cache/kagglehub/datasets/ikynahidwin/depression-student-dataset/versions/1

# %%
import pandas as pd


file_path = '/content/sample_data/Depression.csv'


df = pd.read_csv(file_path)


df.head()
# Out:
#    Gender  Age  Academic Pressure  Study Satisfaction     Sleep Duration  \
# 0    Male   28                2.0                 4.0          7-8 hours
# 1    Male   28                4.0                 5.0          5-6 hours
# 2    Male   25                1.0                 3.0          5-6 hours
# 3    Male   23                1.0                 4.0  More than 8 hours
# 4  Female   31                1.0                 5.0  More than 8 hours
#
#   Dietary Habits Have you ever had suicidal thoughts ?  Study Hours  \
# 0       Moderate                                   Yes            9
# 1        Healthy                                   Yes            7
# 2      Unhealthy                                   Yes           10
# 3      Unhealthy                                   Yes            7
# 4        Healthy                                   Yes            4
#
#    Financial Stress Family History of Mental Illness Depression
# 0                 2                              Yes         No
# 1                 1                              Yes         No
# 2                 4                               No        Yes
# 3                 2                              Yes         No
# 4                 2                              Yes         No

# %%
df.info()

print(df.columns)

for a in df.columns:
 print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-42e5378f2217> in <cell line: 1>()
# ----> 1 df.info()
#       2
#       3 print(df.columns)
#       4
#       5 for a in df.columns:
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Tahap Preprocessing data untuk cek apa kah ada data yang kosong di dataset

# %%
print(df.isnull().sum())
df.describe()
# Out:
# Gender                                   0
# Age                                      0
# Academic Pressure                        0
# Study Satisfaction                       0
# Sleep Duration                           0
# Dietary Habits                           0
# Have you ever had suicidal thoughts ?    0
# Study Hours                              0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64
#               Age  Academic Pressure  Study Satisfaction  Study Hours  \
# count  502.000000         502.000000          502.000000   502.000000
# mean    26.241036           3.003984            3.075697     6.404382
# std      4.896501           1.390007            1.373490     3.742434
# min     18.000000           1.000000            1.000000     0.000000
# 25%     22.000000           2.000000            2.000000     3.000000
# 50%     26.500000           3.000000            3.000000     7.000000
# 75%     30.000000           4.000000            4.000000    10.000000
# max     34.000000           5.000000            5.000000    12.000000
#
#        Financial Stress
# count        502.000000
# mean           2.928287
# std            1.425053
# min            1.000000
# 25%            2.000000
# 50%            3.000000
# 75%            4.000000
# max            5.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Age'].plot(kind='hist', bins=20, title='Age')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Academic Pressure'].plot(kind='hist', bins=20, title='Academic Pressure')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Study Satisfaction'].plot(kind='hist', bins=20, title='Study Satisfaction')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Study Hours'].plot(kind='hist', bins=20, title='Study Hours')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Age', y='Academic Pressure', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Academic Pressure', y='Study Satisfaction', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Study Satisfaction', y='Study Hours', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Study Hours', y='Financial Stress', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Age'].plot(kind='line', figsize=(8, 4), title='Age')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Academic Pressure'].plot(kind='line', figsize=(8, 4), title='Academic Pressure')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Study Satisfaction'].plot(kind='line', figsize=(8, 4), title='Study Satisfaction')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Study Hours'].plot(kind='line', figsize=(8, 4), title='Study Hours')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
newdf = df.isnull().sum()
print(newdf.to_string())
# Out:
# Gender                                   0
# Age                                      0
# Academic Pressure                        0
# Study Satisfaction                       0
# Sleep Duration                           0
# Dietary Habits                           0
# Have you ever had suicidal thoughts ?    0
# Study Hours                              0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0

# %% [markdown]
# Melihat jumlah data antara perempuan dan laki-laki dalam dataset tersebut

# %%
print(df["Gender"].value_counts())
print(df["Depression"].value_counts())
# Out:
# Gender
# Male      267
# Female    235
# Name: count, dtype: int64
# Depression
# Yes    252
# No     250
# Name: count, dtype: int64

# %% [markdown]
# # Distribusi Normal Untuk Age, Academic Pressure, Study Satisfaction, Study Hours, Financial Stress

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["Age"], kde=True)

plt.title("Distribusi umur dengan normal distribusi")
plt.ylabel("Jumlah")
plt.xlabel("Umur")
# Out:
# Text(0.5, 0, 'Umur')

# %% [markdown]
# # Gunakan DecisionTreeClassifier jika masalahnya klasifikasi

# %%
from sklearn.tree import DecisionTreeClassifier  # Gunakan Classifier karena target adalah kategori
import pandas as pd

y = df["Depression"]
X = df.drop(columns=["Depression"])  # Semua kolom kecuali target



X_encoded = pd.get_dummies(X, drop_first=True)

depression_model1 = DecisionTreeClassifier(random_state=1)
depression_model1.fit(X_encoded, y)


print("Making predictions for the following 5 houses:")
print(X.head())
print("The predictions are")
print(depression_model1.predict(X_encoded.head()))
# Out:
# Making predictions for the following 5 houses:
#    Gender  Age  Academic Pressure  Study Satisfaction     Sleep Duration  \
# 0    Male   28                2.0                 4.0          7-8 hours
# 1    Male   28                4.0                 5.0          5-6 hours
# 2    Male   25                1.0                 3.0          5-6 hours
# 3    Male   23                1.0                 4.0  More than 8 hours
# 4  Female   31                1.0                 5.0  More than 8 hours
#
#   Dietary Habits Have you ever had suicidal thoughts ?  Study Hours  \
# 0       Moderate                                   Yes            9
# 1        Healthy                                   Yes            7
# 2      Unhealthy                                   Yes           10
# 3      Unhealthy                                   Yes            7
# 4        Healthy                                   Yes            4
#
#    Financial Stress Family History of Mental Illness
# 0                 2                              Yes
# 1                 1                              Yes
# 2                 4                               No
# 3                 2                              Yes
# 4                 2                              Yes
# The predictions are
# ['No' 'No' 'Yes' 'No' 'No']

# %% [markdown]
# # **Menunjukan bahawa orang kedua mengalami lebih tinggi dari 4 orang lainnya, bisa di buktikan dari lama jam belajar,  dan juga pola makan dan kehidupan yang kurang sehat.
